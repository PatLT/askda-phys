# %%
from askda_phys.tools import reader
from askda_phys.knowledge import build

# %%
url_list = reader.fetch_urls('https://en.wikipedia.org/wiki/Metaphysics',max_links=3000)
len(url_list)
# Out:
# 1626

# %%
link_list = build.fetch_links('https://en.wikipedia.org/wiki/Metaphysics')
len(link_list)
# Out:
# 902

# %%
web = build.build_initial_web(['https://en.wikipedia.org/wiki/Metaphysics'],debug=True)
# Out:
# DEPTH = 0, 1 links
# 	None -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# DEPTH = 1, 902 links
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# 	Metaphysics -> Metaphysics | https://en.wikipedia.org/wiki/Metaphysics
# ...
